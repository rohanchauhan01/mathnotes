# %% [markdown]
# *vector* non-negative magnitude and a direction (does not include location)
#
# can be $(m, \theta)$
#
# usually, (X,Y) and calculate m, theta
#
# scalar multiplication : $a\cdot (m,\theta) = (a\cdot m, theta)\;if\;a\ge0$
#
# if  $a<0$,$a\cdot(m,\theta)$ = $(|a|m,\theta+\pi)$
#
# vector A + B = complete parallelogram

# %%
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import pylab
from mpl_toolkits.mplot3d import Axes3D
# %pylab inline
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d

class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)
fig = plt.figure()
ax = fig.gca(projection='3d')

a = Arrow3D([0,1],[0,1],[0,1], mutation_scale=20, lw=1, arrowstyle="-|>", color="k")
b = Arrow3D([1,2],[0,1],[0,1], mutation_scale=20, lw=1, arrowstyle="-|>", color="r")
ax.add_artist(a)
ax.add_artist(b)
ax.set_zlim3d(-2, 2)                    # viewrange for z-axis should be [-4,4] 
ax.set_ylim3d(-2, 2)                    # viewrange for y-axis should be [-2,2] 
ax.set_xlim3d(-2, 2)                    # viewrange for x-axis should be [-2,2] 

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
1+1
# Out:
# 2
